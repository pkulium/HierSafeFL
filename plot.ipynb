# %%
# %load_ext tensorboard
"""Plot examples of SciencePlot styles."""

# import numpy as np
# import matplotlib.pyplot as plt
# import scienceplots
# pparam = dict(xlabel='Training Epoch', ylabel='Test Accuracy')
# Out:
# 'Plot examples of SciencePlot styles.'

# %%
# %tensorboard --logdir runs_backdoor/
# Out:
# Reusing TensorBoard on port 6039 (pid 32597), started 2 days, 22:18:24 ago. (Use '!kill 32597' to kill it.)
#       <iframe id="tensorboard-frame-7144fb799896274" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7144fb799896274");
#           const url = new URL("/", window.location);
#           const port = 6039;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Out:
# ERROR: Failed to launch TensorBoard (exited with 2).
# Contents of stderr:
# usage: tensorboard [-h] [--helpfull] [--logdir PATH] [--logdir_spec PATH_SPEC]
#                    [--host ADDR] [--bind_all] [--port PORT]
#                    [--reuse_port BOOL] [--load_fast {false,auto,true}]
#                    [--extra_data_server_flags EXTRA_DATA_SERVER_FLAGS]
#                    [--grpc_creds_type {local,ssl,ssl_dev}]
#                    [--grpc_data_provider PORT] [--purge_orphaned_data BOOL]
#                    [--db URI] [--db_import] [--inspect] [--version_tb]
#                    [--tag TAG] [--event_file PATH] [--path_prefix PATH]
#                    [--window_title TEXT] [--max_reload_threads COUNT]
#                    [--reload_interval SECONDS] [--reload_task TYPE]
#                    [--reload_multifile BOOL]
#                    [--reload_multifile_inactive_secs SECONDS]
#                    [--generic_data TYPE]
# ...

# %%
"""Plot examples of SciencePlot styles."""

import numpy as np
import matplotlib.pyplot as plt
import scienceplots
pparam = dict(xlabel='Training Epoch', ylabel='Test Accuracy')

with plt.style.context(['science', 'ieee', 'no-latex']):
    fig, ax = plt.subplots()
    for p in [50, 100, 300, 500, 1000]:
        data = np.loadtxt(f'runs_100_to_1000_clients_iid/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=p)
    ax.legend(title='# clients')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Test Accuracy')  
    fig.savefig('figures/100_1000clients_iid.pdf')
    fig.savefig('figures/100_1000clients_iid.jpg', dpi=300)

# %%
with plt.style.context(['science', 'ieee', 'no-latex']):
    fig, ax = plt.subplots()
    for p in [50, 100, 300, 500, 1000]:
        data = np.loadtxt(f'runs_100_to_1000_clients_noniid/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=p)
    ax.legend(title='# clients')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Test Accuracy')  
    fig.savefig('figures/100_1000clients_noniid.pdf')
    fig.savefig('figures/100_1000clients_noniid.jpg', dpi=300)

# %%
with plt.style.context(['science', 'ieee', 'no-latex']):
    fig, ax = plt.subplots()
    for p in [100, 95, 90, 80, 67, 50]:
        data = np.loadtxt(f'runs_100clients_iid_cifar/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=100 - p)
    ax.legend(title='# malicious clients')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Test Accuracy')  
    fig.savefig('figures/runs_100clients_iid_cifar.pdf')
    fig.savefig('figures/runs_100clients_iid_cifar.jpg', dpi=300)

# %%
with plt.style.context(['science', 'ieee', 'no-latex']):
    fig, ax = plt.subplots()
    for p in [100, 95, 90, 80, 67, 50]:
        data = np.loadtxt(f'runs_100clients_iid/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=100 - p)
    ax.legend(title='# malicious clients')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Test Accuracy')  
    fig.savefig('figures/runs_100clients_iid.pdf')
    fig.savefig('figures/runs_100clients_iid.jpg', dpi=300)

# %%
with plt.style.context(['science', 'ieee', 'no-latex']):
    fig, ax = plt.subplots()
    for p in [100, 95, 90, 80, 67, 50]:
        data = np.loadtxt(f'runs_100clients_noniid_cifar/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=100 - p)
    ax.legend(title='# malicious clients')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Test Accuracy')  
    fig.savefig('figures/runs_100clients_noniid_cifar.pdf')
    fig.savefig('figures/runs_100clients_noniid_cifar.jpg', dpi=300)

# %%
with plt.style.context(['science', 'ieee', 'no-latex']):
    fig, ax = plt.subplots()
    for p in [100, 95, 90, 80, 67, 50]:
        data = np.loadtxt(f'runs_100clients_noniid/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=100 - p)
    ax.legend(title='# malicious clients')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Test Accuracy')  
    fig.savefig('figures/runs_100clients_noniid.pdf')
    fig.savefig('figures/runs_100clients_noniid.jpg', dpi=300)

# %%
with plt.style.context(['science', 'ieee', 'no-latex']):
    fig, ax = plt.subplots()
    for p in [100, 95, 90, 80, 67, 50]:
        data = np.loadtxt(f'runs_100clients_iid_num_communication_200/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=100 - p)
    ax.legend(title='# malicious clients')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Test Accuracy')  
    fig.savefig('figures/runs_100clients_iid_num_communication_200.pdf')
    fig.savefig('figures/runs_100clients_iid_num_communication_200.jpg', dpi=300)

# %%
with plt.style.context(['science', 'ieee', 'no-latex']):
    fig, ax = plt.subplots()
    for p in [100, 95, 90, 80, 67, 50]:
        data = np.loadtxt(f'HierFL/HierFL_runs_100_clients_iid_mnist/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=100 - p)
    ax.legend(title='# malicious clients')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Test Accuracy')  
    fig.savefig('figures/HierFL_runs_100_clients_iid_mnist.pdf')
    fig.savefig('figures/HierFL_runs_100_clients_iid_mnist.jpg', dpi=300)

# %%
with plt.style.context(['science', 'ieee', 'no-latex']):
    fig, ax = plt.subplots()
    for p in [100, 95, 90, 80, 67, 50]:
        data = np.loadtxt(f'HierFL/HierFL_runs_100_clients_noniid_mnist/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=100 - p)
    ax.legend(title='# malicious clients')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Test Accuracy')  
    fig.savefig('figures/HierFL_runs_100_clients_noniid_mnist.pdf')
    fig.savefig('figures/HierFL_runs_100_clients_noniid_mnist.jpg', dpi=300)

# %%
"""Plot examples of SciencePlot styles."""

import numpy as np
import matplotlib.pyplot as plt
import scienceplots
pparam = dict(xlabel='Round', ylabel='Accuracy')

with plt.style.context(['science', 'ieee', 'no-latex', 'std-colors']):
    fig, ax = plt.subplots()
    for p in [100, 95, 90, 80, 67, 50]:
        data = np.loadtxt(f'runs_100clients/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=100 - p)
    ax.legend(title='m(%)')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Accuracy')  
    fig.savefig('figures/runs_100clients.pdf')
    fig.savefig('figures/runs_100clients.eps', dpi=300)

# %%
"""Plot examples of SciencePlot styles."""

import numpy as np
import matplotlib.pyplot as plt
import scienceplots
pparam = dict(xlabel='Round', ylabel='Accuracy')

with plt.style.context(['science', 'ieee', 'no-latex', 'std-colors']):
    fig, ax = plt.subplots()
    for p in [10, 50, 100, 200, 500, 0]:
        data = np.loadtxt(f'runs_500reference/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=p)
        print('%.4f' % y[-1])
    ax.legend(title='# reference')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Accuracy')  
    fig.savefig('figures/runs_500reference.pdf')
    fig.savefig('figures/runs_500reference.jpg', dpi=300)
# Out:
# 0.9203
# 0.9230
# 0.9241
# 0.9240
# 0.9233
# 0.9230

# %%
"""Plot examples of SciencePlot styles."""

import numpy as np
import matplotlib.pyplot as plt
import scienceplots
pparam = dict(xlabel='Round', ylabel='Accuracy')

with plt.style.context(['science', 'ieee', 'no-latex', 'std-colors']):
    fig, ax = plt.subplots()
    for p in [0, 50, 100]:
        data = np.loadtxt(f'runs_coordinate/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=p)
        print('%.4f' % y[-1])
    ax.legend(title='x(%)')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Accuracy')  
    fig.savefig('figures/runs_coordinate.pdf')
    fig.savefig('figures/runs_coordinate.eps', dpi=300)
# Out:
# 0.9241
# 0.9202
# 0.9195

# %%
"""Plot examples of SciencePlot styles."""
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
pparam = dict(xlabel='Round', ylabel='Accuracy')

with plt.style.context(['science', 'ieee', 'no-latex', 'std-colors']):
    fig, ax = plt.subplots()
    for p in [50, 100, 200, 500]:
        data = np.loadtxt(f'runs_500clients/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label= p)
    ax.legend(title='n')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Accuracy')  
    fig.savefig('figures/runs_500clients.pdf')
    fig.savefig('figures/runs_500clients.eps', dpi=300)

# %%
"""Plot examples of SciencePlot styles."""
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
pparam = dict(xlabel='Round', ylabel='Accuracy')

with plt.style.context(['science', 'ieee', 'no-latex', 'std-colors']):
    fig, ax = plt.subplots()
    for p in [95, 90, 80, 67, 50]:
        data = np.loadtxt(f'runs_backdoor/{p}.csv',delimiter = ',', skiprows=1)
        x = data[:, 1]
        y = data[:, -1]
        ax.plot(x, y, label=100 - p)
    ax.legend(title='m(%)')
    ax.autoscale(tight=False)
    ax.set(**pparam)
    # Note: $\mu$ doesn't work with Times font (used by ieee style)
    ax.set_ylabel('Accuracy')  
    fig.savefig('figures/runs_backdoor.pdf')
    fig.savefig('figures/runs_backdoor.eps', dpi=300)
